# %% [markdown]
# <a href="https://colab.research.google.com/github/khyatikhandelwal/Projects/blob/main/Extracting_Tweets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
import pandas as pd

# %%
from config import *
import datetime
# authorization tokens
consumer_key = "DvplOur6qr8kapdSxnjs5ZGUz"
consumer_secret = "qcgmCKsc6vBYoUW75HiQSnX4D6nnp3jnhiqYJ38M9I2SIl7CqC"
access_key = "1405033134249283584-eC2wHguBsPnp7MHfz5ElcSJFgRUHou"
access_secret = "ht2R3xJIXe9MqKebykCSnnWS2VtDQ27FdlNne9luDSCOP"
auth= tweepy.auth.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_key,access_secret)

# %%
# !pip install config

# %%
api = tweepy.API(auth,wait_on_rate_limit=True)

tweets_list = tweepy.Cursor(api.search, q="cryptocurrency OR digital currency OR bitcoin OR etherium OR dodgecoin ",
                            geocode = "20.5937,78.9629,1900km", tweet_mode="extended"
                            ).items(10000)

# %%
output1 = []
for tweet in tweets_list:
    text = tweet._json["full_text"]
    print(text)
    created_at = tweet.created_at
    location = tweet.user._json['geo_enabled']
    
    line = {'text' : text, 'location': location, 'created_at' : created_at}
    output1.append(line)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# #cryptocurrency #Airdrop #BSC #Bitcoin #ETH #SafeMoonSpace #SMSP #Airdropstario
# 📢 #Octopus ($oct) has been added to @DCGco’s public portfolio.
#
# ✅ Digital Currency Group builds and support bitcoin and blockchain companies by leveraging insights, network, and access to capital.
#
# #NEAR  #CryptocurrencyNews https://t.co/uLqIhACrXI
# @CryptoRoyals @GameStationIO As Education for crypto currency is necessary nowadays , what’s your plan to to attract those people who don’t know about cryptocurrency?
# @MDSHORI36288393
# @NayonRo72673383
# @Mzmulhaque1
# Bitcoin ATMs have already been installed at Circle K stores in 30 states. https://t.co/U03MUhwIuq #Cryptocurrency #Bitcoin #InvestSmart
# Please, someone stop it! 😭 #Bitcoin #cryptocurrency
# @getFUFU @bscstation This is a Fantastic project with great potential.The team's dedication and ingenuity with excellent fan support will make this the envy of the crypto world
# ...

# %%
output1 = pd.DataFrame(output1)

print(output1)
# Out:
#                                                    text  ...          created_at
# 0     How To Use Blockchain in Marketing Data Securi...  ... 2021-09-27 13:08:16
# 1     @airdropblgspot @nttcapp Great opportunity \n ...  ... 2021-09-27 13:06:37
# 2     @airdropblgspot @nttcapp this is a great proje...  ... 2021-09-27 13:06:20
# 3     قم دائمًا بإجراء البحث الخاص بك قبل أن تستثمر ...  ... 2021-09-27 13:05:25
# 4     @nttcapp This is a good project and has potens...  ... 2021-09-27 13:04:21
# ...                                                 ...  ...                 ...
# 6480  RBA Looking to Hire #CBDCs Experts to Contribu...  ... 2021-09-18 10:00:01
# 6481  The Biden administration is moving to disrupt ...  ... 2021-09-18 09:53:01
# 6482  Excellent Project and congratulations to the t...  ... 2021-09-18 09:47:14
# 6483  @LandBusiness1 Very nice project,\nI supportin...  ... 2021-09-18 09:45:50
# 6484  This project has a very bright future, Don't m...  ... 2021-09-18 09:36:45
#
# ...

# %%
name= "Arthniti Data Week 1.xlsx"
output1.to_excel(name)
